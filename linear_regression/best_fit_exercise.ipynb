# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('canada.csv');
df.head(10)
# Out:
#    year          PCI
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583
# 5  1975  5998.144346
# 6  1976  7062.131392
# 7  1977  7100.126170
# 8  1978  7247.967035
# 9  1979  7602.912681

# %%
# Try all basic data frame commands
df.head(1)
df.tail(5)
# Out:
#     year          PCI
# 42  2012  42665.25597
# 43  2013  42676.46837
# 44  2014  41039.89360
# 45  2015  35175.18898
# 46  2016  34229.19363

# %%
plt.scatter(df.year, df.PCI)
plt.plot(df.year, reg.predict(df[['year']]), color='red')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=47, step=1)

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='str')

# %%
df.describe()
# Out:
#               year           PCI
# count    47.000000     47.000000
# mean   1993.000000  18920.137063
# std      13.711309  12034.679438
# min    1970.000000   3399.299037
# 25%    1981.500000   9526.914515
# 50%    1993.000000  16426.725480
# 75%    2004.500000  27458.601420
# max    2016.000000  42676.468370

# %%
# IMPORTING AND EXPORTING .xlsx, .parquet, .csv are supported
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df.PCI)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.predict([[2020]])
# Out:
# /home/slash/Coding/AIML/machine-learning/linear_venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
# Predicted Per capita income PCI for the year 2020 is 41288.69409442
