# %%
import sys
print(sys.executable)
# !pip install scikit-learn
# Out:
# /home/slash/Coding/AIML/machine-learning/linear_venv/bin/python

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("linear.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
plt.xlabel('area sqr ft')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area,reg.predict(df[['area']]), color='blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# /home/slash/Coding/AIML/machine-learning/linear_venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
d = pd.read_csv("linear_area.csv")
d.head(3)
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200

# %%
p = reg.predict(d)

# %%
d['prices'] = p

# %%
d
# Out:
#    area         prices
# 0  2600  533664.383562
# 1  3000  587979.452055
# 2  3200  615136.986301
# 3  3600  669452.054795
# 4  4000  723767.123288

# %%
d.to_csv("prediction.csv")
